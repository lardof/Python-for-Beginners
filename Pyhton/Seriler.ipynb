# %%
import pandas as pd

# %%
idx = (2015, 2016, 2017, 2018, 2019, 2020, 2021)
dt = (150,170,185,200,195,130,90)

# %%
pd.Series(data = dt, index = idx)
# Out:
# 2015    150
# 2016    170
# 2017    185
# 2018    200
# 2019    195
# 2020    130
# 2021     90
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(pd.Series(dt, index = idx))

# %%
# idx = (2015, 2016, 2017, 2018, 2019, 2020, 2021)
# dt = (150,170,185,200,195,130,90)

sozluk = {2015:150, 2016:170, 2017:185, 2018:200, 2019:195, 2020:130, 2021:90}
pd.Series(sozluk)
# Out:
# 2015    150
# 2016    170
# 2017    185
# 2018    200
# 2019    195
# 2020    130
# 2021     90
# dtype: int64

# %%
plt.plot(pd.Series(sozluk),"red")
plt.show()

# %%
idx = (2015, 2016, 2017, 2018, 2019, 2020, 2021)
dt = (150,170,185,200,195,130,90)

pd.Series(data = dt, index = idx)

seri = pd.Series(data = dt, index = idx)

# %%
tablo = pd.DataFrame(seri, columns = ["Ton"])
tablo
# Out:
#       Ton
# 2015  150
# 2016  170
# 2017  185
# 2018  200
# 2019  195
# 2020  130
# 2021   90

# %%
tablo = tablo.reset_index()

# %%
tablo
# Out:
#    index  Ton
# 0   2015  150
# 1   2016  170
# 2   2017  185
# 3   2018  200
# 4   2019  195
# 5   2020  130
# 6   2021   90

# %%
tablo.columns
# Out:
# Index(['index', 'Ton'], dtype='object')

# %%
tablo = tablo.rename(columns={"index":"Yil"})

# %%
tablo
# Out:
#     Yil  Ton
# 0  2015  150
# 1  2016  170
# 2  2017  185
# 3  2018  200
# 4  2019  195
# 5  2020  130
# 6  2021   90
