# %%
from sklearn.datasets import load_diabetes
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
diabetes = load_diabetes()
X = diabetes.data[:, np.newaxis,2]
y = diabetes.target

# %%
plt.scatter(x,y)
plt.xlabel("X:Kitle Endeksi")
plt.ylabel("Y:Diyabet")
# Out:
# Text(0, 0.5, 'Y:Diyabet')

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y)
plt.xlabel("x:Kitle Endeksi")
plt.ylabel("Y:Diyabet")
plt.show()

# %%
plt.scatter(X,y)
plt.plot(X, lin_reg.predict(x),color = "red", label = "Lineer Regresyon")

plt.legend()
plt.xlabel("X:Kitle Endeksi")
plt.ylabel("y:Diyabet")
plt.show()

# %%
plt.scatter(X,y)
plt.plot(X, lin_reg.predict(X),color = "red", label = "Lineer Regresyon")
plt.plot(X, lin_reg_poly.predict(X_poly),color = "yellow", label = "Polinom Regresyon")
plt.title("Diyabet Verisi")
plt.legend()
plt.xlabel("X:Kitle Endeksi")
plt.ylabel("y:Diyabet")
plt.show()
