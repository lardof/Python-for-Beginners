# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dizi1 = np.linspace(1,10,100)
dizi2 = dizi1 ** 3

# %%
fig = plt.figure()
fig1 = fig.add_axes([0.1,0.1,0.7,0.7])
fig1.plot(dizi1,dizi2,"g")

fig2 = fig.add_axes([0.3,0.3,0.3,0.3])
fig2.plot(dizi2,dizi1,"r")
