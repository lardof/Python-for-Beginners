# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\mete\PS4 Data.csv',encoding='unicode_escape')

# %%
data
# Out:
#                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           1034 non-null   object
#  1   Year           825 non-null    float64
#  2   Genre          1034 non-null   object
#  3   Publisher      825 non-null    object
#  4   North America  1034 non-null   float64
#  5   Europe         1034 non-null   float64
#  6   Japan          1034 non-null   float64
#  7   Rest of World  1034 non-null   float64
#  8   Global         1034 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 72.8+ KB

# %%
data.describe()
# Out:
#               Year  North America       Europe        Japan  Rest of World  \
# count   825.000000    1034.000000  1034.000000  1034.000000    1034.000000
# mean   2015.966061       0.204613     0.248714     0.033636       0.089014
# std       1.298360       0.563471     0.785491     0.108344       0.249410
# min    2013.000000       0.000000     0.000000     0.000000       0.000000
# 25%    2015.000000       0.000000     0.000000     0.000000       0.000000
# 50%    2016.000000       0.020000     0.000000     0.000000       0.010000
# 75%    2017.000000       0.120000     0.130000     0.030000       0.050000
# max    2020.000000       6.180000     9.710000     2.170000       3.020000
#
#             Global
# count  1034.000000
# mean      0.576054
# std       1.583534
# min       0.000000
# 25%       0.000000
# 50%       0.060000
# 75%       0.357500
# max      19.390000

# %%
data = data.dropna()
data
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1025                  Biomutant  2019.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Rockstar Games           6.06    9.71   0.60           3.02
# 1                     Activision           6.18    6.05   0.41           2.44
# ...

# %%
data = data.reset_index(drop=True)
data
# Out:
#                           Game    Year             Genre  \
# 0           Grand Theft Auto V  2014.0            Action
# 1    Call of Duty: Black Ops 3  2015.0           Shooter
# 2        Red Dead Redemption 2  2018.0  Action-Adventure
# 3           Call of Duty: WWII  2017.0           Shooter
# 4                      FIFA 18  2017.0            Sports
# ..                         ...     ...               ...
# 820                  Biomutant  2019.0            Action
# 821                    de Blob  2017.0          Platform
# 822           Chaos on Deponia  2017.0         Adventure
# 823                  Code Vein  2018.0            Action
# 824   Radial G Racing Revolved  2017.0            Racing
#
#                       Publisher  North America  Europe  Japan  Rest of World  \
# 0                Rockstar Games           6.06    9.71   0.60           3.02
# 1                    Activision           6.18    6.05   0.41           2.44
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           825 non-null    object
#  1   Year           825 non-null    float64
#  2   Genre          825 non-null    object
#  3   Publisher      825 non-null    object
#  4   North America  825 non-null    float64
#  5   Europe         825 non-null    float64
#  6   Japan          825 non-null    float64
#  7   Rest of World  825 non-null    float64
#  8   Global         825 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 58.1+ KB

# %%
data.dtypes
# Out:
# Game              object
# Year             float64
# Genre             object
# Publisher         object
# North America    float64
# Europe           float64
# Japan            float64
# Rest of World    float64
# Global           float64
# dtype: object

# %%
data['Year'] = data["Year"].astype(int)

# %%
data.dtypes
# Out:
# Game              object
# Year               int32
# Genre             object
# Publisher         object
# North America    float64
# Europe           float64
# Japan            float64
# Rest of World    float64
# Global           float64
# dtype: object

# %%
data
# Out:
#                           Game  Year             Genre  \
# 0           Grand Theft Auto V  2014            Action
# 1    Call of Duty: Black Ops 3  2015           Shooter
# 2        Red Dead Redemption 2  2018  Action-Adventure
# 3           Call of Duty: WWII  2017           Shooter
# 4                      FIFA 18  2017            Sports
# ..                         ...   ...               ...
# 820                  Biomutant  2019            Action
# 821                    de Blob  2017          Platform
# 822           Chaos on Deponia  2017         Adventure
# 823                  Code Vein  2018            Action
# 824   Radial G Racing Revolved  2017            Racing
#
#                       Publisher  North America  Europe  Japan  Rest of World  \
# 0                Rockstar Games           6.06    9.71   0.60           3.02
# 1                    Activision           6.18    6.05   0.41           2.44
# ...

# %%
data.Global.value_counts()           #burdan son 116 satirin 0 oldugnunu anliyoruz ve onlari data setinden cikartiyoruz
# Out:
# 0.00    116
# 0.02     39
# 0.04     39
# 0.03     37
# 0.01     34
#        ...
# 2.06      1
# 2.05      1
# 2.02      1
# 1.98      1
# 1.21      1
# Name: Global, Length: 206, dtype: int64

# %%
data = data[data["Global"] != 0]
data
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2014            Action
# 1           Call of Duty: Black Ops 3  2015           Shooter
# 2               Red Dead Redemption 2  2018  Action-Adventure
# 3                  Call of Duty: WWII  2017           Shooter
# 4                             FIFA 18  2017            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2017      Role-Playing
# 705                         Teslagrad  2014          Platform
# 706  Darius Burst: Chronicle Saviours  2017            Action
# 707   The Escapists: The Walking Dead  2016            Action
# 708                    Super Meat Boy  2016          Platform
#
#                Publisher  North America  Europe  Japan  Rest of World  Global
# 0         Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709 entries, 0 to 708
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           709 non-null    object
#  1   Year           709 non-null    int32
#  2   Genre          709 non-null    object
#  3   Publisher      709 non-null    object
#  4   North America  709 non-null    float64
#  5   Europe         709 non-null    float64
#  6   Japan          709 non-null    float64
#  7   Rest of World  709 non-null    float64
#  8   Global         709 non-null    float64
# dtypes: float64(5), int32(1), object(3)
# memory usage: 52.6+ KB

# %%
data.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   709.000000     709.000000  709.000000  709.000000     709.000000
# mean   2015.953456       0.298406    0.362581    0.048928       0.129803
# std       1.172582       0.659710    0.926771    0.127947       0.292334
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.020000    0.000000    0.000000       0.010000
# 50%    2016.000000       0.070000    0.050000    0.010000       0.030000
# 75%    2017.000000       0.240000    0.310000    0.050000       0.110000
# max    2018.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  709.000000
# mean     0.839803
# std      1.853915
# min      0.010000
# 25%      0.060000
# 50%      0.170000
# 75%      0.720000
# max     19.390000

# %%
sales_g = data.Global.sum()
sales_n = data["North America"].sum()
sales_e = data.Europe.sum()
sales_j = data.Japan.sum()
sales_r = data["Rest of World"].sum()

print("Global Satislar : {}".format(sales_g))
print("North America Satislar : {}".format(sales_n))
print("Europe Satislar : {}".format(sales_e))
print("Japan Satislar : {}".format(sales_j))
print("Rest of World Satislar : {}".format(sales_r))
# Out:
# Global Satislar : 595.4200000000001
# North America Satislar : 211.57
# Europe Satislar : 257.07
# Japan Satislar : 34.69
# Rest of World Satislar : 92.03

# %%
labels = data.describe().columns[1:].tolist()
labels
# Out:
# ['North America', 'Europe', 'Japan', 'Rest of World', 'Global']

# %%
values =[sales_n, sales_e, sales_j, sales_r, sales_g]

# %%
plt.bar(labels, values,color ="b")
plt.xlabel('Region')
plt.ylabel('Billion')
plt.title('Global Sales By Region')




plt.show()

# %%
labels = data.describe().columns[1:-1].tolist()
values =[sales_n, sales_e, sales_j, sales_r,]
plt.pie(values, labels = labels, autopct = "%1.1f%%")
plt.title('Global Sales By Region')


plt.show()

# %%
sales_by_year = data.groupby("Year")[["North America", "Europe", "Japan", "Rest of World"]].sum()

fig, ax = plt.subplots()
ax.plot(sales_by_year.index, sales_by_year["North America"], label="North America")
ax.plot(sales_by_year.index, sales_by_year["Europe"], label="Europe")
ax.plot(sales_by_year.index, sales_by_year["Japan"], label="Japan")
ax.plot(sales_by_year.index, sales_by_year["Rest of World"], label="Rest of World")
ax.set_xlabel("Year")
ax.set_ylabel("Sales (millions)")
ax.set_title("Video Game Sales by Year")
ax.legend()
plt.show()

# %%
data.Year.value_counts()
# Out:
# 2017    240
# 2016    201
# 2015    139
# 2014     78
# 2018     35
# 2013     16
# Name: Year, dtype: int64

# %%
sales_by_year = data.groupby("Year")["Global"].sum()
print(sales_by_year)
# Out:
# Year
# 2013     28.76
# 2014    115.85
# 2015    133.99
# 2016    135.72
# 2017    130.90
# 2018     50.20
# Name: Global, dtype: float64

# %%
sales_by_year.plot(kind = "bar")
plt.xlabel("Year")
plt.xlabel("Global Sales")
plt.title("Global Sales by Year")
plt.show()

# %%
sales_by_year = data.groupby("Year")["North America"].sum()
sales_by_year.plot(kind = "bar")
plt.xlabel("Year")
plt.xlabel("North America")
plt.title("North America")
plt.show()

# %%
data
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2014            Action
# 1           Call of Duty: Black Ops 3  2015           Shooter
# 2               Red Dead Redemption 2  2018  Action-Adventure
# 3                  Call of Duty: WWII  2017           Shooter
# 4                             FIFA 18  2017            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2017      Role-Playing
# 705                         Teslagrad  2014          Platform
# 706  Darius Burst: Chronicle Saviours  2017            Action
# 707   The Escapists: The Walking Dead  2016            Action
# 708                    Super Meat Boy  2016          Platform
#
#                Publisher  North America  Europe  Japan  Rest of World  Global
# 0         Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
sales_of_games = data.head(10).groupby("Game")["Global"].sum().sort_values(ascending = False)
sales_of_games.plot(kind = "bar")
plt.xlabel("Year")
plt.xlabel("Global")
plt.title("Global Sales By Year")
plt.show()

# %%
sales_by_publisher = data.groupby("Publisher")[["Global"]].sum()
sales_by_publisher["Global"] = sales_by_publisher.sum(axis=1)

fig, ax = plt.subplots()
ax.bar(top_publishers.index, top_publishers["Global"])
ax.set_xlabel("Publisher")
ax.set_ylabel("Global Sales (millions)")
ax.set_title("Top 10 Publishers by Global Sales")

plt.xticks(rotation=90)  # Firmaların yatay olarak yazdırılması için x ekseni etiketlerini 90 derece döndürüyoruz

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2 sales_by_publisher["Global"] = sales_by_publisher.sum(axis=1)
#       4 fig, ax = plt.subplots()
# ----> 5 ax.bar(top_publishers.index, top_publishers["Global"])
#       6 ax.set_xlabel("Publisher")
#       7 ax.set_ylabel("Global Sales (millions)")
#
# NameError: name 'top_publishers' is not defined

# %%
sales_by_Publisher = (data.groupby("Publisher")["Global"].sum().sort_values(ascending = False))[0:10]
sales_by_Publisher.plot(kind = "bar", color = "green")

plt.xlabel("Publisher")
plt.ylabel("Global Sales (millions)")
plt.title("Top 10 Publishers by Global Sales")
plt.show()

# %%
sales_by_publisher = data.groupby("Publisher")[["Global"]].sum()
sales_by_publisher["Global"] = sales_by_publisher.sum(axis=1)
sales_by_Publisher.plot(kind = "bar", color = "green")

plt.xlabel("Publisher")
plt.ylabel("Global Sales (millions)")
plt.title("Top 10 Publishers by Global Sales")
plt.show()
