# %%
import matplotlib.pyplot as plt

x = [10,20,30,50]
y = ["X","Y","Z","T"]
plt.pie(x,labels = y);

# %%
plt.figure(figsize=(4,4))
x = [10,20,20,50]
y = ["X","Y","Z","T"]
z = [0,0.1,0,0]   #burda neyi degistirisen o cikar
plt.pie(x,labels = y, explode=z);
