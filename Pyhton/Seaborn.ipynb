# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/lardof/Pyhton/community_health_MLR.csv')

# %%
df
# Out:
#      yas  cins  irk   kilo    boy  visits
# 0     47     0    4  112.0  165.0      28
# 1     26     1    3  128.0  168.0      23
# 2     26     1    2   91.0  173.0      14
# 3     39     1    3  108.0  185.0      21
# 4     55     1    1   90.0  155.0      27
# ..   ...   ...  ...    ...    ...     ...
# 995   43     0    5  124.0  173.0      22
# 996   34     0    4  112.0  193.0      16
# 997   54     0    2  141.0  190.0      27
# 998   38     1    5   29.0  190.0       7
# 999   62     0    4   97.0  170.0      22
#
# [1000 rows x 6 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      yas  cins  irk   kilo    boy  visits
# 0     47     0    4  112.0  165.0      28
# 1     26     1    3  128.0  168.0      23
# 2     26     1    2   91.0  173.0      14
# 3     39     1    3  108.0  185.0      21
# 4     55     1    1   90.0  155.0      27
# ..   ...   ...  ...    ...    ...     ...
# 995   43     0    5  124.0  173.0      22
# 996   34     0    4  112.0  193.0      16
# 997   54     0    2  141.0  190.0      27
# 998   38     1    5   29.0  190.0       7
# 999   62     0    4   97.0  170.0      22
#
# [1000 rows x 6 columns]>

# %%
df.describe()
# Out:
#                yas         cins         irk         kilo          boy  \
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     45.019000     0.481000     3.15500    90.283000   170.914000
# std      14.839166     0.499889     1.14817    23.958024    15.947694
# min       0.000000     0.000000     1.00000    20.000000   117.000000
# 25%      36.000000     0.000000     2.00000    75.000000   160.000000
# 50%      45.000000     0.000000     3.00000    89.000000   170.000000
# 75%      55.000000     1.000000     4.00000   107.000000   183.000000
# max      89.000000     1.000000     5.00000   161.000000   218.000000
#
#             visits
# count  1000.000000
# mean     19.956000
# std       6.455055
# min       2.000000
# 25%      15.000000
# 50%      20.000000
# 75%      24.000000
# max      40.000000

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(data=df, x='kilo', y='boy')
# Out:
# <Axes: xlabel='kilo', ylabel='boy'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6), dpi=100)
sns.scatterplot(data=df, x='kilo', y='boy', hue='cins', size='irk');

# %% [markdown]
# # Countplot

# %%
sns.countplot(data=df, x='irk')
# Out:
# <Axes: xlabel='irk', ylabel='count'>

# %%
df['irk'].value_counts()
# Out:
# 3    304
# 4    261
# 2    220
# 5    136
# 1     79
# Name: irk, dtype: int64

# %%
plt.figure(figsize=(12,8), dpi=200)
sns.countplot(data=df ,x='visits')
# Out:
# <Axes: xlabel='visits', ylabel='count'>
